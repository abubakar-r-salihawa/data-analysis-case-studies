# %% [markdown]
# # Laptop Price Analysis
#
# **Author:** Abubakar Rabiu Salihawa
# **Brand:** SALNERA
#
# This reproducible case study analyses laptop price drivers and compares regression models on held-out data. The reusable workflow is kept in `laptop_analysis.py` so the notebook remains clean and easy to review.

# %% [markdown]
# ## Questions
#
# 1. Which hardware variables are most strongly associated with price?
# 2. How do manufacturer price averages differ?
# 3. Which regression model performs best on unseen records?
# 4. What are the limitations of this dataset?

# %%
from laptop_analysis import run_analysis

results = run_analysis()
results.round(3)

# %% [markdown]
# ## Interpretation
#
# The validated run found Gradient Boosting to be the strongest model, with test R² of approximately **0.477** and RMSE of approximately **347.12** price units. RAM and processor-related variables were among the strongest predictors.
#
# The moderate score indicates that important market variables—such as product age, processor generation, condition, warranty and location—are not fully represented. This project should therefore be treated as an analytical demonstration rather than a production pricing engine.

# %% [markdown]
# ## Attribution
#
# The source exercise and dataset were encountered through IBM Skills Network learning materials. The workflow has been restructured, corrected and extended as independent portfolio work. See the repository `ATTRIBUTION.md`.
